# %% [markdown]
# ### About Dataset

# %% [markdown]
# About Dataset
# This dataset provides detailed records of road accidents that occurred during January 2021. It includes information such as the accident date, day of the week, junction control, accident severity, geographical coordinates, lighting and weather conditions, vehicle details, and more. The data is valuable for analyzing and understanding the factors contributing to road accidents in this urban area, aiding in the development of strategies for improved road safety.
#
# Accident_Index: A unique identifier for each accident record.
#
# Accident Date: The date on which the accident occurred (format: DD/MM/YYYY).
#
# Day_of_Week: The day of the week when the accident took place.
#
# Junction_Control : Describes the type of junction control at the accident location (e.g., "Give way or uncontrolled").
#
# Junction_Detail: Provides additional details about the junction where the accident occurred (e.g., "T or staggered junction").
#
# Accident_Severity: Indicates the severity of the accident (e.g., "Serious").
#
# Latitude: The geographic latitude of the accident location.
#
# Light_Conditions: Describes the lighting conditions at the time of the accident (e.g., "Daylight").
#
# Local_Authority_(District): The local authority district where the accident occurred.
#
# Carriageway_Hazards: Describes any hazards present on the carriageway at the time of the accident (e.g., "None").
#
# Longitude: The geographic longitude of the accident location.
#
# Number_of_Casualties: The total number of casualties involved in the accident.
#
# Number_of_Vehicles: The total number of vehicles involved in the accident.
#
# Police_Force: The police force that handled the accident.
#
# Road_Surface_Conditions: Describes the surface conditions of the road at the time of the accident (e.g., "Dry").
#
# Road_Type: Specifies the type of road where the accident occurred (e.g., "One way street").
#
# Speed_limit: The speed limit applicable to the road where the accident occurred.
#
# Time: The time of day when the accident happened (format: HH:MM).
#
# Urban_or_Rural_Area: Indicates whether the accident occurred in an urban or rural area.
#
# Weather_Conditions: Describes the weather conditions at the time of the accident (e.g., "Fine no high winds").
#
# Vehicle_Type: Specifies the type of vehicle involved in the accident (e.g., "Car," "Taxi/Private hire car").

# %% [markdown]
# # Reason Behinds The Road Accident?

# %% [markdown]
# ### Life cycle of Machine learning Project
# #### Understanding the Problem Statement
# #### Data Collection
# #### Data Checks to perform
# #### Exploratory data analysis
# #### Data Pre-Processing
# #### Model Training
# #### Choose best model

# %% [markdown]
# ### 1) Problem Statement
#     The data is valuable for analyzing and understanding the factors contributing to road accidents in this urban area,
#     aiding in the development of strategies for improved road safety

# %% [markdown]
# ### 2) Data Collection
#     Dataset Source - Data Collected from Kaggle.
#     The Consists of 21 columns and 307973 rows.

# %% [markdown]
# ### 2.1 Import Data and Required Packages
#     Importing Pandas, Numpy, Matplotlib, Seaborn, Warnings Library.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Import the csv Data as pandas DataFrame

# %%
def read_data():
    try:
        data = pd.read_csv("C:/Kaggle_dataset/Road Accident Data/Road Accident Data.csv")
        return data
    except Exception as e:
        print("Data Path Not Found and Error is in the read data function")

# %% [markdown]
# ### Calling the data & Show Top 5 Records

# %%
df = read_data()
print(df.head())
# Out:
#   Accident_Index Accident Date Day_of_Week          Junction_Control  \
# 0  200901BS70001      1/1/2021    Thursday  Give way or uncontrolled
# 1  200901BS70002      1/5/2021      Monday  Give way or uncontrolled
# 2  200901BS70003      1/4/2021      Sunday  Give way or uncontrolled
# 3  200901BS70004      1/5/2021      Monday       Auto traffic signal
# 4  200901BS70005      1/6/2021     Tuesday       Auto traffic signal
#
#            Junction_Detail Accident_Severity   Latitude  \
# 0  T or staggered junction           Serious  51.512273
# 1               Crossroads           Serious  51.514399
# 2  T or staggered junction            Slight  51.486668
# 3  T or staggered junction           Serious  51.507804
# 4               Crossroads           Serious  51.482076
#
#         Light_Conditions Local_Authority_(District) Carriageway_Hazards  ...  \
# 0               Daylight     Kensington and Chelsea                None  ...
# ...

# %% [markdown]
# ### Information

# %%
df1 = df.copy()
print(df1.head())
print(df1.info())
print(df1.shape)
# Out:
#   Accident_Index Accident Date Day_of_Week          Junction_Control  \
# 0  200901BS70001      1/1/2021    Thursday  Give way or uncontrolled
# 1  200901BS70002      1/5/2021      Monday  Give way or uncontrolled
# 2  200901BS70003      1/4/2021      Sunday  Give way or uncontrolled
# 3  200901BS70004      1/5/2021      Monday       Auto traffic signal
# 4  200901BS70005      1/6/2021     Tuesday       Auto traffic signal
#
#            Junction_Detail Accident_Severity   Latitude  \
# 0  T or staggered junction           Serious  51.512273
# 1               Crossroads           Serious  51.514399
# 2  T or staggered junction            Slight  51.486668
# 3  T or staggered junction           Serious  51.507804
# 4               Crossroads           Serious  51.482076
#
#         Light_Conditions Local_Authority_(District) Carriageway_Hazards  ...  \
# 0               Daylight     Kensington and Chelsea                None  ...
# ...

# %%
print(df1.describe())
# Out:
#             Latitude      Longitude  Number_of_Casualties  Number_of_Vehicles  \
# count  307973.000000  307973.000000         307973.000000       307973.000000
# mean       52.487005      -1.368884              1.356882            1.829063
# std         1.339011       1.356092              0.815857            0.710477
# min        49.914488      -7.516225              1.000000            1.000000
# 25%        51.485248      -2.247937              1.000000            1.000000
# 50%        52.225943      -1.349258              1.000000            2.000000
# 75%        53.415517      -0.206810              1.000000            2.000000
# max        60.598055       1.759398             48.000000           32.000000
#
#          Speed_limit
# count  307973.000000
# mean       38.866037
# std        14.032933
# min        10.000000
# 25%        30.000000
# 50%        30.000000
# 75%        50.000000
# max        70.000000

# %%
df1.isna().sum()
# Out:
# Accident_Index                   0
# Accident Date                    0
# Day_of_Week                      0
# Junction_Control                 0
# Junction_Detail                  0
# Accident_Severity                0
# Latitude                         0
# Light_Conditions                 0
# Local_Authority_(District)       0
# Carriageway_Hazards              3
# Longitude                        0
# Number_of_Casualties             0
# Number_of_Vehicles               0
# Police_Force                     0
# Road_Surface_Conditions        317
# Road_Type                     1534
# Speed_limit                      0
# Time                            17
# Urban_or_Rural_Area              0
# Weather_Conditions            6057
# Vehicle_Type                     0
# dtype: int64

# %%
df1 = df1.dropna(axis=0)
df1
# Out:
#        Accident_Index Accident Date Day_of_Week              Junction_Control  \
# 0       200901BS70001      1/1/2021    Thursday      Give way or uncontrolled
# 1       200901BS70002      1/5/2021      Monday      Give way or uncontrolled
# 2       200901BS70003      1/4/2021      Sunday      Give way or uncontrolled
# 3       200901BS70004      1/5/2021      Monday           Auto traffic signal
# 4       200901BS70005      1/6/2021     Tuesday           Auto traffic signal
# ...               ...           ...         ...                           ...
# 307968  201091NM01760     2/18/2022    Thursday  Data missing or out of range
# 307969  201091NM01881     2/21/2022      Sunday  Data missing or out of range
# 307970  201091NM01935     2/23/2022     Tuesday      Give way or uncontrolled
# 307971  201091NM01964     2/23/2022     Tuesday      Give way or uncontrolled
# 307972  201091NM02142     2/28/2022      Sunday      Give way or uncontrolled
#
# ...

# %%
per = round(((df1.isna().sum() * 100)/ (df1.shape[0])),2)
per
# Out:
# Accident_Index                0.0
# Accident Date                 0.0
# Day_of_Week                   0.0
# Junction_Control              0.0
# Junction_Detail               0.0
# Accident_Severity             0.0
# Latitude                      0.0
# Light_Conditions              0.0
# Local_Authority_(District)    0.0
# Carriageway_Hazards           0.0
# Longitude                     0.0
# Number_of_Casualties          0.0
# Number_of_Vehicles            0.0
# Police_Force                  0.0
# Road_Surface_Conditions       0.0
# Road_Type                     0.0
# Speed_limit                   0.0
# Time                          0.0
# Urban_or_Rural_Area           0.0
# Weather_Conditions            0.0
# Vehicle_Type                  0.0
# dtype: float64

# %%
df1[df1.duplicated() == True ]
# Out:
#       Accident_Index Accident Date Day_of_Week              Junction_Control  \
# 50483       2.01E+12      1/6/2021     Tuesday  Data missing or out of range
#
#                            Junction_Detail Accident_Severity   Latitude  \
# 50483  Not at junction or within 20 metres            Slight  53.648498
#
#       Light_Conditions Local_Authority_(District) Carriageway_Hazards  ...  \
# 50483         Daylight                 Calderdale                None  ...
#
#        Number_of_Casualties  Number_of_Vehicles    Police_Force  \
# 50483                     1                   1  West Yorkshire
#
#       Road_Surface_Conditions           Road_Type Speed_limit   Time  \
# 50483            Frost or ice  Single carriageway          50  16:35
#
#       Urban_or_Rural_Area  Weather_Conditions Vehicle_Type
# 50483               Rural  Fine no high winds          Car
#
# [1 rows x 21 columns]

# %%
plt.figure(figsize=(8,4))
sns.boxplot(df1)
plt.tight_layout()
plt.show()

# %%
cat_col = []
num_col = []
for i in df1.columns:
    if df1[i].dtypes == object:
        cat_col.append(i)
    else:
        num_col.append(i)

# %%
print(cat_col)
print(num_col)
# Out:
# ['Accident_Index', 'Accident Date', 'Day_of_Week', 'Junction_Control', 'Junction_Detail', 'Accident_Severity', 'Light_Conditions', 'Local_Authority_(District)', 'Carriageway_Hazards', 'Police_Force', 'Road_Surface_Conditions', 'Road_Type', 'Time', 'Urban_or_Rural_Area', 'Weather_Conditions', 'Vehicle_Type']
# ['Latitude', 'Longitude', 'Number_of_Casualties', 'Number_of_Vehicles', 'Speed_limit']

# %%
for i in cat_col:
    print("The Number of ",i)
    print(df1[i].value_counts())
    print("************************************************")
# Out:
# The Number of  Accident_Index
# 2.01E+12         107294
# 2.01E+46              3
# 2.01E+31              2
# 2.01E+199             2
# 2.01E+254             2
#                   ...
# 200934NK10649         1
# 200934NK10679         1
# 200934NK11109         1
# 200934NK11179         1
# 201091NM02142         1
# Name: Accident_Index, Length: 193173, dtype: int64
# ************************************************
# The Number of  Accident Date
# 10/6/2021     669
# 2/11/2021     667
# 11/13/2021    663
# 12/4/2021     653
# 11/12/2021    644
#              ...
# 12/28/2022    179
# 12/27/2022    172
# 12/30/2022    166
# 12/25/2022    142
# 1/10/2022     120
# Name: Accident Date, Length: 730, dtype: int64
# ************************************************
# The Number of  Day_of_Week
# Friday       49286
# Wednesday    45331
# Tuesday      45221
# Thursday     44495
# Monday       42855
# Saturday     40544
# Sunday       32760
# Name: Day_of_Week, dtype: int64
# ...

# %%
for i in cat_col:
    print("The Number of ",i)
    print(df1[i].unique())
    print("************************************************")
# Out:
# The Number of  Accident_Index
# ['200901BS70001' '200901BS70002' '200901BS70003' ... '201091NM01935'
#  '201091NM01964' '201091NM02142']
# ************************************************
# The Number of  Accident Date
# ['1/1/2021' '1/5/2021' '1/4/2021' '1/6/2021' '1/8/2021' '1/2/2021'
#  '1/7/2021' '1/10/2021' '1/16/2021' '1/12/2021' '1/9/2021' '1/17/2021'
#  '1/25/2021' '1/26/2021' '1/19/2021' '1/27/2021' '1/21/2021' '1/22/2021'
#  '1/31/2021' '2/3/2021' '1/29/2021' '1/28/2021' '1/20/2021' '1/15/2021'
#  '2/9/2021' '1/23/2021' '2/10/2021' '1/30/2021' '2/12/2021' '2/16/2021'
#  '2/14/2021' '2/18/2021' '2/21/2021' '2/15/2021' '2/20/2021' '2/27/2021'
#  '1/18/2021' '2/7/2021' '2/23/2021' '2/22/2021' '2/26/2021' '3/4/2021'
#  '3/3/2021' '3/6/2021' '2/17/2021' '3/9/2021' '3/10/2021' '3/2/2021'
#  '2/25/2021' '3/14/2021' '2/28/2021' '2/11/2021' '3/1/2021' '3/13/2021'
#  '3/17/2021' '2/24/2021' '3/20/2021' '2/5/2021' '3/21/2021' '3/24/2021'
# ...

# %%
import matplotlib.ticker as ticker
cols = ['Day_of_Week','Light_Conditions','Carriageway_Hazards','Road_Surface_Conditions','Road_Type','Accident_Severity','Urban_or_Rural_Area', 'Weather_Conditions', 'Vehicle_Type']
plt.figure(figsize=(14,14))
for i,col in enumerate(cols,1):
    plt.subplot(4,3,i)
    graph = sns.countplot(data=df1,x=col)
    for p in graph.patches:
        graph.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
        ha='center', va='baseline')
    plt.xticks(rotation=60)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,8))
for i,col in enumerate(num_col,1):
    plt.subplot(3,3,i)
    sns.histplot(data=df1,x=col,kde=True,bins=10)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,5))
graph = sns.barplot(data = df1,x ='Light_Conditions',y ='Number_of_Casualties',hue='Urban_or_Rural_Area',errorbar=None,estimator=sum)
for p in graph.patches:
    graph.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
    ha='center', va='baseline')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,5))
graph= sns.barplot(data = df1,x ='Road_Type',y ='Speed_limit',hue='Urban_or_Rural_Area',errorbar=None,estimator= 'sum' )
for p in graph.patches:
    graph.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
    ha='center', va='baseline')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,5))
graph = sns.barplot(data = df1,x ='Accident_Severity',y ='Speed_limit',hue='Urban_or_Rural_Area',errorbar=None,estimator=sum )
for p in graph.patches:
    graph.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
    ha='center', va='baseline')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data = df1,x ='Accident Date',y ='Number_of_Vehicles',hue = 'Accident_Severity',size='Accident_Severity',palette='viridis')
plt.tight_layout()
plt.show()

# %%
df1.columns
print(cat_col)
# Out:
# ['Accident_Index', 'Accident Date', 'Day_of_Week', 'Junction_Control', 'Junction_Detail', 'Accident_Severity', 'Light_Conditions', 'Local_Authority_(District)', 'Carriageway_Hazards', 'Police_Force', 'Road_Surface_Conditions', 'Road_Type', 'Time', 'Urban_or_Rural_Area', 'Weather_Conditions', 'Vehicle_Type']

# %%
plt.figure(figsize=(8,5))
sns.barplot(data = df1,x ='Light_Conditions',y ='Speed_limit',hue='Weather_Conditions',errorbar=None,estimator=sum,palette='coolwarm')
plt.tight_layout()
plt.show()

# %%
df1.describe()
# Out:
#             Latitude      Longitude  Number_of_Casualties  Number_of_Vehicles  \
# count  300492.000000  300492.000000         300492.000000       300492.000000
# mean       52.485289      -1.361865              1.359451            1.830521
# std         1.341325       1.354010              0.818283            0.711747
# min        49.914488      -7.516225              1.000000            1.000000
# 25%        51.484853      -2.241654              1.000000            1.000000
# 50%        52.212246      -1.341125              1.000000            2.000000
# 75%        53.415892      -0.203734              1.000000            2.000000
# max        60.598055       1.759398             48.000000           32.000000
#
#          Speed_limit
# count  300492.000000
# mean       38.932551
# std        14.062392
# min        10.000000
# 25%        30.000000
# 50%        30.000000
# 75%        50.000000
# max        70.000000

# %%
cat_col
# Out:
# ['Accident_Index',
#  'Accident Date',
#  'Day_of_Week',
#  'Junction_Control',
#  'Junction_Detail',
#  'Accident_Severity',
#  'Light_Conditions',
#  'Local_Authority_(District)',
#  'Carriageway_Hazards',
#  'Police_Force',
#  'Road_Surface_Conditions',
#  'Road_Type',
#  'Time',
#  'Urban_or_Rural_Area',
#  'Weather_Conditions',
#  'Vehicle_Type']

# %%
plt.figure(figsize=(10,4))
Police_Force_value_counts = df1['Police_Force'].value_counts().head(5)
colors=sns.color_palette('pastel', len(Police_Force_value_counts))
plt.pie(Police_Force_value_counts, labels=Police_Force_value_counts.index, 
 autopct='%1.2f%%', startangle=140,colors=colors, wedgeprops=dict(width=0.4))

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,4))
Speed_limit_value_counts = df1['Speed_limit'].value_counts().head(5)
colors=sns.color_palette('pastel', len(Speed_limit_value_counts))
plt.pie(Speed_limit_value_counts, labels=Speed_limit_value_counts.index, 
 autopct='%1.2f%%', startangle=140,colors=colors, wedgeprops=dict(width=0.4))

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,4))
colors=sns.color_palette('deep', len(Speed_limit_value_counts))
plt.pie(Speed_limit_value_counts,autopct='%1.2f%%',labels=Speed_limit_value_counts.index,startangle=120)
plt.tight_layout()
plt.show()

# %%
Speed_limit_value_counts = df1['Speed_limit'].value_counts().head(5)
Speed_limit_value_counts
# Out:
# 30    194511
# 60     46056
# 40     25163
# 70     21970
# 50     10000
# Name: Speed_limit, dtype: int64

# %%
corr = df1.corr()
sns.heatmap(corr,annot=True,cmap='viridis')
# Out:
# <Axes: >

# %%
df1.columns
# Out:
# Index(['Accident_Index', 'Accident Date', 'Day_of_Week', 'Junction_Control',
#        'Junction_Detail', 'Accident_Severity', 'Latitude', 'Light_Conditions',
#        'Local_Authority_(District)', 'Carriageway_Hazards', 'Longitude',
#        'Number_of_Casualties', 'Number_of_Vehicles', 'Police_Force',
#        'Road_Surface_Conditions', 'Road_Type', 'Speed_limit', 'Time',
#        'Urban_or_Rural_Area', 'Weather_Conditions', 'Vehicle_Type'],
#       dtype='object')

# %%
plt.figure(figsize=(10,5))
graph = sns.barplot(data = df1,x ='Light_Conditions',y ='Number_of_Casualties',hue='Accident_Severity',errorbar=None,estimator='mean' )
for p in graph.patches:
    graph.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
    ha='center', va='baseline')
plt.tight_layout()
plt.show()

# %%
df1
# Out:
#        Accident_Index Accident Date Day_of_Week              Junction_Control  \
# 0       200901BS70001      1/1/2021    Thursday      Give way or uncontrolled
# 1       200901BS70002      1/5/2021      Monday      Give way or uncontrolled
# 2       200901BS70003      1/4/2021      Sunday      Give way or uncontrolled
# 3       200901BS70004      1/5/2021      Monday           Auto traffic signal
# 4       200901BS70005      1/6/2021     Tuesday           Auto traffic signal
# ...               ...           ...         ...                           ...
# 307968  201091NM01760     2/18/2022    Thursday  Data missing or out of range
# 307969  201091NM01881     2/21/2022      Sunday  Data missing or out of range
# 307970  201091NM01935     2/23/2022     Tuesday      Give way or uncontrolled
# 307971  201091NM01964     2/23/2022     Tuesday      Give way or uncontrolled
# 307972  201091NM02142     2/28/2022      Sunday      Give way or uncontrolled
#
# ...

# %%
df1['Year'] = df1['Accident Date'].str.split('/').str[2]
df1['Day'] = df1['Accident Date'].str.split('/').str[1]
df1['Month'] = df1['Accident Date'].str.split('/').str[0]

# %%
df1['Carriageway_Hazards'].value_counts()
# Out:
# None                                               295187
# Other object on road                                 2194
# Any animal in carriageway (except ridden horse)      1597
# Pedestrian in carriageway - not injured               679
# Previous accident                                     508
# Vehicle load on road                                  327
# Name: Carriageway_Hazards, dtype: int64

# %%
df1['Day_of_Week'].value_counts()
# Out:
# Friday       49286
# Wednesday    45331
# Tuesday      45221
# Thursday     44495
# Monday       42855
# Saturday     40544
# Sunday       32760
# Name: Day_of_Week, dtype: int64

# %%
plt.figure(figsize=(10,5))
graph = sns.barplot(data = df1,x ='Light_Conditions',y ='Speed_limit',hue='Year',errorbar=None,estimator=sum)
for p in graph.patches:
    graph.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
    ha='center', va='baseline')
plt.tight_layout()
plt.show()

# %%
df1.columns
# Out:
# Index(['Accident_Index', 'Accident Date', 'Day_of_Week', 'Junction_Control',
#        'Junction_Detail', 'Accident_Severity', 'Latitude', 'Light_Conditions',
#        'Local_Authority_(District)', 'Carriageway_Hazards', 'Longitude',
#        'Number_of_Casualties', 'Number_of_Vehicles', 'Police_Force',
#        'Road_Surface_Conditions', 'Road_Type', 'Speed_limit', 'Time',
#        'Urban_or_Rural_Area', 'Weather_Conditions', 'Vehicle_Type', 'Year',
#        'Day', 'Month'],
#       dtype='object')

# %%
plt.figure(figsize=(8,4))
sns.scatterplot(data = df1,x ='Speed_limit',y ='Number_of_Casualties',hue='Year')
plt.tight_layout()
plt.show()

# %%
import matplotlib.ticker as ticker
plt.figure(figsize=(14,8))
graph = sns.barplot(data = df1,x ='Vehicle_Type',y ='Speed_limit',hue='Year',errorbar=None,estimator=sum)
for p in graph.patches:
    graph.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
    ha='center', va='baseline')
    plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
import matplotlib.ticker as ticker
plt.figure(figsize=(14,8))
graph = sns.barplot(data = df1,x ='Vehicle_Type',y ='Number_of_Casualties',hue='Year',errorbar=None,estimator=sum)
for p in graph.patches:
    graph.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
    ha='center', va='baseline')
    plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
a = df1[['Number_of_Casualties','Year']]
a
# Out:
#         Number_of_Casualties  Year
# 0                          1  2021
# 1                         11  2021
# 2                          1  2021
# 3                          1  2021
# 4                          1  2021
# ...                      ...   ...
# 307968                     2  2022
# 307969                     1  2022
# 307970                     1  2022
# 307971                     1  2022
# 307972                     1  2022
#
# [300492 rows x 2 columns]

# %%
plt.figure(figsize=(8,5))
graph = a[(a['Number_of_Casualties'] > 8) & (a['Year'] == '2021')].value_counts().head(10).plot(kind='bar')
for p in graph.patches:
    graph.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
    ha='center', va='baseline')
plt.xlabel('Number of Casualities in year 2021')
plt.ylabel('Count of casualties')
plt.title("Top 10 Casualities by year 2021")
plt.legend('Urban_or_Rural_Area')
plt.tight_layout()
plt.show()

# %%
df1['Number_of_Casualties'].value_counts()
# Out:
# 1     228951
# 2      49095
# 3      14111
# 4       5261
# 5       1880
# 6        709
# 7        236
# 8        100
# 9         44
# 10        34
# 12        14
# 11        14
# 13         9
# 14         7
# 17         5
# 18         4
# 16         3
# 15         3
# 21         2
# 24         2
# 19         1
# 27         1
# 48         1
# 40         1
# 26         1
# 22         1
# 42         1
# 43         1
# Name: Number_of_Casualties, dtype: int64

# %%
graph = df1.groupby('Year')['Number_of_Casualties'].sum().plot(kind='bar')
for p in graph.patches:
    graph.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
    ha='center', va='baseline')
plt.show()

# %%
plt.figure(figsize=(8,4))
graph = sns.barplot(data = df1,x ='Year',y ='Number_of_Casualties',errorbar=None,estimator=sum)
for p in graph.patches:
    graph.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
    ha='center', va='baseline')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,4))
graph = sns.barplot(data = df1,x ='Month',y ='Number_of_Casualties',errorbar=None,estimator=sum)
for p in graph.patches:
    graph.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
    ha='center', va='baseline')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,4))
graph = sns.lineplot(data = df1,x ='Day_of_Week',y ='Number_of_Casualties',hue='Road_Type',errorbar=None,estimator=sum)
for p in graph.patches:
    graph.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
    ha='center', va='baseline')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,4))
graph = sns.lineplot(data = df1,x ='Day',y ='Number_of_Casualties',hue='Year',errorbar=None,estimator=sum)
for p in graph.patches:
    graph.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
    ha='center', va='baseline')
plt.tight_layout()
plt.show()
